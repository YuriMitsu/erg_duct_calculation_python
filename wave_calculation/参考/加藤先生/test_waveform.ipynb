# %%
import numpy as np
import matplotlib.pylab as plt
fig = plt.figure()
ax1 = fig.add_subplot(3,1,1,xlabel='psi',ylabel='X')
ax2 = fig.add_subplot(3,1,2,xlabel='psi',ylabel='Y')
ax3 = fig.add_subplot(3,1,3,xlabel='psi',ylabel='Z')
psi = np.linspace(-4*np.pi,4*np.pi,401)

ex = np.sin(psi)
ey = np.cos(psi)
ez = np.cos(psi)
bx = np.cos(psi)
by = np.sin(psi)
bz = np.sin(psi)

ax1.plot(psi,ex,label='Ex',c='red')
ax1.plot(psi,bx,label='Bx',c='blue')
ax2.plot(psi,ey,label='Ey',c='red')
ax2.plot(psi,by,label='By',c='blue')
ax3.plot(psi,ey,label='Ez',c='red')
ax3.plot(psi,by,label='Bz',c='blue')

ax1.legend(bbox_to_anchor=(1,1))
ax2.legend(bbox_to_anchor=(1,1))
ax3.legend(bbox_to_anchor=(1,1))
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pylab as plt
#fig = plt.figure()
fig,axes = plt.subplots(3,1,sharex='col')
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

psi = np.linspace(-4*np.pi,4*np.pi,401)
ex = np.cos(psi)
ey = np.sin(psi)
ez = np.cos(psi)
bx = np.sin(psi)
by = np.cos(psi)
bz = np.sin(psi)

th_deg = 30
phi_deg = 30
th = np.deg2rad(th_deg)
phi = np.deg2rad(phi_deg)

ex1 = np.cos(th)*np.cos(phi)*ex -np.sin(phi)*ey + np.sin(th)*np.cos(phi)*ez
ey1 = np.cos(th)*np.sin(phi)*ex +np.cos(phi)*ey + np.sin(th)*np.sin(phi)*ez
ez1 = -np.sin(th)*ex + np.cos(th)*ez
bx1 = np.cos(th)*np.cos(phi)*bx -np.sin(phi)*by + np.sin(th)*np.cos(phi)*bz
by1 = np.cos(th)*np.sin(phi)*bx +np.cos(phi)*by + np.sin(th)*np.sin(phi)*bz
bz1 = -np.sin(th)*bx + np.cos(th)*bz

ax1.plot(psi,ex,label='Ex',c='red',ls=':')
ax1.plot(psi,bx,label='Bx',c='blue',ls=':')
ax1.plot(psi,ex1,label='Ex1',c='red')
ax1.plot(psi,bx1,label='Bx1',c='blue')

ax2.plot(psi,ey,label='Ey',c='red',ls=':')
ax2.plot(psi,by,label='By',c='blue',ls=':')
ax2.plot(psi,ey1,label='Ey1',c='red')
ax2.plot(psi,by1,label='By1',c='blue')

ax3.plot(psi,ez,label='Ez',c='red',ls=':')
ax3.plot(psi,bz,label='Bz',c='blue',ls=':')
ax3.plot(psi,ez1,label='Ez1',c='red')
ax3.plot(psi,bz1,label='Bz1',c='blue')

ax1.legend(bbox_to_anchor=(1,1))
ax2.legend(bbox_to_anchor=(1,1))
ax3.legend(bbox_to_anchor=(1,1))
#ax1.set_title("theta %i" %th)
ax1.set_title("theta %i: phi %i" %(th_deg,phi_deg))
ax3.set_xlabel('psi [rad]')
fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pylab as plt
import time
#fig = plt.figure()
fig,axes = plt.subplots(3,1,sharex='col')
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

psi = np.linspace(-4*np.pi,4*np.pi,401)
ex = np.cos(psi)
ey = np.sin(psi)
ez = np.cos(psi)
bx = np.sin(psi)
by = np.cos(psi)
bz = np.sin(psi)

fig.tight_layout()

ims = []
for ii in range(13):
    th_deg = 30
    phi_deg = ii*30
    th = np.deg2rad(th_deg)
    phi = np.deg2rad(phi_deg)
    print((th_deg,phi_deg))

    ex1 = np.cos(th)*np.cos(phi)*ex -np.sin(phi)*ey + np.sin(th)*np.cos(phi)*ez
    ey1 = np.cos(th)*np.sin(phi)*ex +np.cos(phi)*ey + np.sin(th)*np.sin(phi)*ez
    ez1 = -np.sin(th)*ex + np.cos(th)*ez
    bx1 = np.cos(th)*np.cos(phi)*bx -np.sin(phi)*by + np.sin(th)*np.cos(phi)*bz
    by1 = np.cos(th)*np.sin(phi)*bx +np.cos(phi)*by + np.sin(th)*np.sin(phi)*bz
    bz1 = -np.sin(th)*bx + np.cos(th)*bz

    ax1.plot(psi,ex,label='Ex',c='red',ls=':')
    ax1.plot(psi,bx,label='Bx',c='blue',ls=':')
    ax1.plot(psi,ex1,label='Ex1',c='red')
    ax1.plot(psi,bx1,label='Bx1',c='blue')

    ax2.plot(psi,ey,label='Ey',c='red',ls=':')
    ax2.plot(psi,by,label='By',c='blue',ls=':')
    ax2.plot(psi,ey1,label='Ey1',c='red')
    ax2.plot(psi,by1,label='By1',c='blue')

    ax3.plot(psi,ez,label='Ez',c='red',ls=':')
    ax3.plot(psi,bz,label='Bz',c='blue',ls=':')
    ax3.plot(psi,ez1,label='Ez1',c='red')
    ax3.plot(psi,bz1,label='Bz1',c='blue')

    ax1.legend(bbox_to_anchor=(1,1))
    ax2.legend(bbox_to_anchor=(1,1))
    ax3.legend(bbox_to_anchor=(1,1))
    ax1.set_title("theta %i: phi %i" %(th_deg,phi_deg))
    ax3.set_xlabel('psi [rad]')

    plt.show()
    time.sleep(.5)
# Out:
# (30, 0)
# (30, 30)
# (30, 60)
# (30, 90)
# (30, 120)
# (30, 150)
# (30, 180)
# (30, 210)
# (30, 240)
# (30, 270)
# (30, 300)
# (30, 330)
# (30, 360)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
import matplotlib.animation as anim
#fig = plt.figure()
fig,axes = plt.subplots(3,1,sharex='col')
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

psi = np.linspace(-4*np.pi,4*np.pi,401)
ex = np.cos(psi)
ey = np.sin(psi)
ez = np.cos(psi)
bx = np.sin(psi)
by = np.cos(psi)
bz = np.sin(psi)

fig.tight_layout()

def update(ii):
    ax1.cla()
    ax2.cla()
    ax3.cla()
    
    th_deg = 30
    phi_deg = ii*30
    th = np.deg2rad(th_deg)
    phi = np.deg2rad(phi_deg)
    print((th_deg,phi_deg))

    ex1 = np.cos(th)*np.cos(phi)*ex -np.sin(phi)*ey + np.sin(th)*np.cos(phi)*ez
    ey1 = np.cos(th)*np.sin(phi)*ex +np.cos(phi)*ey + np.sin(th)*np.sin(phi)*ez
    ez1 = -np.sin(th)*ex + np.cos(th)*ez
    bx1 = np.cos(th)*np.cos(phi)*bx -np.sin(phi)*by + np.sin(th)*np.cos(phi)*bz
    by1 = np.cos(th)*np.sin(phi)*bx +np.cos(phi)*by + np.sin(th)*np.sin(phi)*bz
    bz1 = -np.sin(th)*bx + np.cos(th)*bz

    ax1.plot(psi,ex,label='Ex',c='red',ls=':')
    ax1.plot(psi,bx,label='Bx',c='blue',ls=':')
    ax1.plot(psi,ex1,label='Ex1',c='red')
    ax1.plot(psi,bx1,label='Bx1',c='blue')

    ax2.plot(psi,ey,label='Ey',c='red',ls=':')
    ax2.plot(psi,by,label='By',c='blue',ls=':')
    ax2.plot(psi,ey1,label='Ey1',c='red')
    ax2.plot(psi,by1,label='By1',c='blue')

    ax3.plot(psi,ez,label='Ez',c='red',ls=':')
    ax3.plot(psi,bz,label='Bz',c='blue',ls=':')
    ax3.plot(psi,ez1,label='Ez1',c='red')
    ax3.plot(psi,bz1,label='Bz1',c='blue')

    ax1.legend()
    ax1.legend(bbox_to_anchor=(1,1))
    ax2.legend(bbox_to_anchor=(1,1))
    ax3.legend(bbox_to_anchor=(1,1))
    ax1.set_ylim(-1.2,1.2)
    ax2.set_ylim(-1.2,1.2)
    ax3.set_ylim(-1.2,1.2)
    ax1.set_title("theta %02d: phi %03d" %(th_deg,phi_deg))
    ax3.set_xlabel('psi [rad]')

ani = anim.FuncAnimation(fig,update,interval=200,frames=12)
ani.save("sample.gif",writer='imagemagick')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (30, 0)
# (30, 0)
# (30, 30)
# (30, 60)
# (30, 90)
# (30, 120)
# (30, 150)
# (30, 180)
# (30, 210)
# (30, 240)
# (30, 270)
# (30, 300)
# (30, 330)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
import matplotlib.animation as animation

fig = plt.figure()
x = np.arange(0,10,0.1)

ims=[]
for a in range(50):
    y = np.sin(x-a)
    im = plt.plot(x,y,"r")
    ims.append(im)

ani = animation.ArtistAnimation(fig,ims)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
import matplotlib.animation as anim
#fig = plt.figure()
fig,axes = plt.subplots(3,1,sharex='col')
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

psi = np.linspace(-4*np.pi,4*np.pi,401)
ex = np.cos(psi)
ey = np.sin(psi)
ez = np.cos(psi)
bx = np.sin(psi)
by = np.cos(psi)
bz = np.sin(psi)

fig.tight_layout()

def update1(ii,aa):
    ax1.cla()
    ax2.cla()
    ax3.cla()
    
    th_deg = jj
    phi_deg = ii*30
    th = np.deg2rad(th_deg)
    phi = np.deg2rad(phi_deg)
    print((th_deg,phi_deg))

    ex1 = np.cos(th)*np.cos(phi)*ex -np.sin(phi)*ey + np.sin(th)*np.cos(phi)*ez
    ey1 = np.cos(th)*np.sin(phi)*ex +np.cos(phi)*ey + np.sin(th)*np.sin(phi)*ez
    ez1 = -np.sin(th)*ex + np.cos(th)*ez
    bx1 = np.cos(th)*np.cos(phi)*bx -np.sin(phi)*by + np.sin(th)*np.cos(phi)*bz
    by1 = np.cos(th)*np.sin(phi)*bx +np.cos(phi)*by + np.sin(th)*np.sin(phi)*bz
    bz1 = -np.sin(th)*bx + np.cos(th)*bz

    ax1.plot(psi,ex,label='Ex',c='red',ls=':')
    ax1.plot(psi,bx,label='Bx',c='blue',ls=':')
    ax1.plot(psi,ex1,label='Ex1',c='red')
    ax1.plot(psi,bx1,label='Bx1',c='blue')

    ax2.plot(psi,ey,label='Ey',c='red',ls=':')
    ax2.plot(psi,by,label='By',c='blue',ls=':')
    ax2.plot(psi,ey1,label='Ey1',c='red')
    ax2.plot(psi,by1,label='By1',c='blue')

    ax3.plot(psi,ez,label='Ez',c='red',ls=':')
    ax3.plot(psi,bz,label='Bz',c='blue',ls=':')
    ax3.plot(psi,ez1,label='Ez1',c='red')
    ax3.plot(psi,bz1,label='Bz1',c='blue')

    ax1.legend()
    ax1.legend(bbox_to_anchor=(1,1))
    ax2.legend(bbox_to_anchor=(1,1))
    ax3.legend(bbox_to_anchor=(1,1))
    ax1.set_ylim(-1.2,1.2)
    ax2.set_ylim(-1.2,1.2)
    ax3.set_ylim(-1.2,1.2)
    ax1.set_title("theta %02d: phi %03d" %(th_deg,phi_deg))
    ax3.set_xlabel('psi [rad]')

th_deg = 30
ani = anim.FuncAnimation(fig,update1,fargs=(th_deg,),interval=200,frames=12)
fname = "model_th%02d.gif" % th_deg
print(fname)
ani.save("sample1.gif",writer='imagemagick')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# MovieWriter stderr:
# convert: unexpected end-of-file '-': No such file or directory @ error/rgb.c/ReadRGBImage/247.
# convert: no images defined `sample1.gif' @ error/convert.c/ConvertImageCommand/3322.
# model_th30.gif
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/miniforge3/envs/test1/lib/python3.9/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     235         try:
# --> 236             yield self
#     237         finally:
#
# ~/miniforge3/envs/test1/lib/python3.9/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1159             for anim in all_anim:
# -> 1160                 anim._init_draw()  # Clear the initial frame
# ...

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
import matplotlib.animation as anim
#fig = plt.figure()
fig,axes = plt.subplots(3,1,sharex='col')
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]

psi = np.linspace(-4*np.pi,4*np.pi,401)
ex = np.cos(psi)
ey = np.sin(psi)
ez = np.cos(psi)
bx = np.sin(psi)
by = np.cos(psi)
bz = np.sin(psi)

fig.tight_layout()

def update(ii,th_deg):
    ax1.cla()
    ax2.cla()
    ax3.cla()
    
#    th_deg = 30
    phi_deg = ii*30
    th = np.deg2rad(th_deg)
    phi = np.deg2rad(phi_deg)
    print((th_deg,phi_deg))

    ex1 = np.cos(th)*np.cos(phi)*ex -np.sin(phi)*ey + np.sin(th)*np.cos(phi)*ez
    ey1 = np.cos(th)*np.sin(phi)*ex +np.cos(phi)*ey + np.sin(th)*np.sin(phi)*ez
    ez1 = -np.sin(th)*ex + np.cos(th)*ez
    bx1 = np.cos(th)*np.cos(phi)*bx -np.sin(phi)*by + np.sin(th)*np.cos(phi)*bz
    by1 = np.cos(th)*np.sin(phi)*bx +np.cos(phi)*by + np.sin(th)*np.sin(phi)*bz
    bz1 = -np.sin(th)*bx + np.cos(th)*bz

    ax1.plot(psi,ex,label='Ex',c='red',ls=':')
    ax1.plot(psi,bx,label='Bx',c='blue',ls=':')
    ax1.plot(psi,ex1,label='Ex1',c='red')
    ax1.plot(psi,bx1,label='Bx1',c='blue')

    ax2.plot(psi,ey,label='Ey',c='red',ls=':')
    ax2.plot(psi,by,label='By',c='blue',ls=':')
    ax2.plot(psi,ey1,label='Ey1',c='red')
    ax2.plot(psi,by1,label='By1',c='blue')

    ax3.plot(psi,ez,label='Ez',c='red',ls=':')
    ax3.plot(psi,bz,label='Bz',c='blue',ls=':')
    ax3.plot(psi,ez1,label='Ez1',c='red')
    ax3.plot(psi,bz1,label='Bz1',c='blue')

    ax1.legend()
    ax1.legend(bbox_to_anchor=(1,1))
    ax2.legend(bbox_to_anchor=(1,1))
    ax3.legend(bbox_to_anchor=(1,1))
    ax1.set_ylim(-1.2,1.2)
    ax2.set_ylim(-1.2,1.2)
    ax3.set_ylim(-1.2,1.2)
    ax1.set_title("theta %03d: phi %03d" %(th_deg,phi_deg))
    ax3.set_xlabel('psi [rad]')

for jj in range(7):
    th_deg = jj*30
    ani = anim.FuncAnimation(fig,update,fargs=(th_deg,),interval=200,frames=12)
    fname = "model_th%03d.gif" % th_deg
    print(fname)
    ani.save(fname,writer='imagemagick')
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# model_th000.gif
# (0, 0)
# (0, 0)
# (0, 30)
# (0, 60)
# (0, 90)
# (0, 120)
# (0, 150)
# (0, 180)
# (0, 210)
# (0, 240)
# (0, 270)
# (0, 300)
# (0, 330)
# model_th030.gif
# (30, 0)
# (30, 0)
# (30, 30)
# (30, 60)
# (30, 90)
# (30, 120)
# (30, 150)
# (30, 180)
# (30, 210)
# (30, 240)
# (30, 270)
# (30, 300)
# (30, 330)
# model_th060.gif
# (60, 0)
# (60, 0)
# (60, 30)
# (60, 60)
# (60, 90)
# (60, 120)
# (60, 150)
# (60, 180)
# (60, 210)
# (60, 240)
# (60, 270)
# (60, 300)
# (60, 330)
# model_th090.gif
# (90, 0)
# (90, 0)
# (90, 30)
# (90, 60)
# (90, 90)
# (90, 120)
# (90, 150)
# (90, 180)
# (90, 210)
# (90, 240)
# (90, 270)
# (90, 300)
# (90, 330)
# model_th120.gif
# (120, 0)
# (120, 0)
# (120, 30)
# (120, 60)
# (120, 90)
# (120, 120)
# (120, 150)
# (120, 180)
# (120, 210)
# (120, 240)
# (120, 270)
# (120, 300)
# (120, 330)
# model_th150.gif
# (150, 0)
# (150, 0)
# (150, 30)
# (150, 60)
# (150, 90)
# (150, 120)
# (150, 150)
# ...
